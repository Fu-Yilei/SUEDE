# %%
import ete3, numpy

# %%
with open("../NCBITaxa/resultparsnp/parsnp.tree", "r") as f:
    l = f.readline()
l = l[:-1]

# %%
tree = ete3.Tree(l)

# %%
print(tree)
# Out:
#                         /-'GCF_002447355.1_ASM244735v1_genomic.fna'
#                      /-|
#                     |   \-'GCF_002447515.1_ASM244751v1_genomic.fna'
#                   /-|
#                  |  |   /-'GCF_002447975.1_ASM244797v1_genomic.fna'
#                  |   \-|
#                  |     |   /-'GCF_002448135.1_ASM244813v1_genomic.fna'
#                /-|      \-|
#               |  |         \-'GCF_002448155.1_ASM244815v1_genomic.fna'
#               |  |
#               |  |   /-'GCF_002448035.1_ASM244803v1_genomic.fna'
#               |   \-|
#               |     |   /-'GCF_002447155.1_ASM244715v1_genomic.fna'
#             /-|      \-|
#            |  |        |   /-'GCF_002446975.1_ASM244697v1_genomic.fna'
#            |  |         \-|
#            |  |            \-'GCF_002446995.1_ASM244699v1_genomic.fna'
#            |  |
#            |  |   /-'GCF_002447795.1_ASM244779v1_genomic.fna'
#            |  |  |
# ...

# %%
for leaf in tree:
    print(leaf.dist)
# Out:
# 0.00072
# 0.00048
# 0.00224
# 0.00014
# 0.00014
# 0.01683
# 0.00329
# 0.0
# 0.0
# 0.00449
# 0.01018
# 0.00962
# 0.01569
# 0.01422
# 0.00442
# 0.00095
# 0.00144
# 0.00334
# 0.00096
# 0.00096
# 0.0008
# 0.00144
# 0.00048
# 0.01693
# 0.01668
# 0.00014
# 0.01231
# 0.00799
# 0.0238
# 0.02964
# 0.03971
# 0.00193
# 0.00176
# 0.00064
# 0.00048
# 0.00024
# 0.0008
# 0.00024
# 0.00337
# 0.00426
# 0.00014
# 0.00014
# 0.00587
# 0.00539
# 0.0092
# 0.01238
# 0.00718
# 0.00668
# 0.0008
# 0.0004
# 0.00014
# 0.00646
# 0.0
# 0.0
# 0.00659
# 0.00586
# 0.00127
# 0.00178
# 0.00305
# 0.00378
# 0.01076
# 0.01124
# 0.0252
# 0.01747
# 0.00386
# 0.00313
# 0.00032
# 0.00064
# 0.00024
# 0.0
# 0.0
# 0.00732
# 0.00072
# 0.00144
# 0.00014
# 0.02564
# 0.00377
# 0.00305
# 0.00926
# 0.00699
# 0.00079
# 0.00934
# 0.00983
# 0.00522
# 0.00393
# 0.00369
# 0.00361
# 0.00273
# 0.00305
# 0.00096
# 0.00048
# 0.00048
# 0.01438
# 0.0004
# 0.00806
# 0.00072
# 0.00024
# 0.00402
# 0.00394
# 0.00659
# 0.00537
# 0.0017
# 0.00352
# ...

# %%
numpy.random.randint(10)
# Out:
# 4

# %%
[a, b, c] = (1, 2 , 3)

# %%
b
# Out:
# 2

# %%
["A", "B"] in ["A", "B", "C"]
# Out:
# False
